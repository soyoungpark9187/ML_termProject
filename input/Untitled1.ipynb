# %%
import pandas as pd
import numpy as np
import random
import math
from matplotlib import pyplot as plt
import sklearn.preprocessing as preprocessing
from scipy.stats import spearmanr
import seaborn as sn

# %%
data = pd.read_csv('Indicators.csv')
data.shape
# Out:
# (5656458, 6)

# %%
data['Year'].unique()
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015], dtype=int64)

# %%
data.head()
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
data['Year'].unique()
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015], dtype=int64)

# %%
japan=data[data['CountryName']=='Japan']

# %%
japan['Year'].unique()
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015], dtype=int64)

# %%
from50=japan[japan['Year']>1950]

# %%
from50.head()
# Out:
#       CountryName CountryCode  \
# 12804       Japan         JPN
# 12805       Japan         JPN
# 12806       Japan         JPN
# 12807       Japan         JPN
# 12808       Japan         JPN
#
#                                            IndicatorName      IndicatorCode  \
# 12804  Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 12805  Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 12806  Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 12807  Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 12808  Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
#
#        Year      Value
# 12804  1960   4.120200
# 12805  1960  55.970117
# 12806  1960   8.930725
# 12807  1960  47.039393
# 12808  1960   6.223620

# %%
from50['IndicatorName'].unique()
# Out:
# array(['Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Age dependency ratio (% of working-age population)',
#        'Age dependency ratio, old (% of working-age population)',
#        'Age dependency ratio, young (% of working-age population)',
#        'Alternative and nuclear energy (% of total energy use)',
#        'Arms exports (SIPRI trend indicator values)',
#        'Arms imports (SIPRI trend indicator values)',
#        'Birth rate, crude (per 1,000 people)',
#        'CO2 emissions (kg per 2005 US$ of GDP)', 'CO2 emissions (kt)',
#        'CO2 emissions (metric tons per capita)',
#        'CO2 emissions from electricity and heat production, total (% of total fuel combustion)',
#        'CO2 emissions from gaseous fuel consumption (% of total)',
#        'CO2 emissions from gaseous fuel consumption (kt)',
#        'CO2 emissions from liquid fuel consumption (% of total)',
#        'CO2 emissions from liquid fuel consumption (kt)',
# ...

# %%
gdp = from50[from50['IndicatorName']=='GDP at market prices (current US$)']

# %%
gdp.head()
# Out:
#        CountryName CountryCode                       IndicatorName  \
# 12861        Japan         JPN  GDP at market prices (current US$)
# 37962        Japan         JPN  GDP at market prices (current US$)
# 65583        Japan         JPN  GDP at market prices (current US$)
# 94083        Japan         JPN  GDP at market prices (current US$)
# 122866       Japan         JPN  GDP at market prices (current US$)
#
#          IndicatorCode  Year         Value
# 12861   NY.GDP.MKTP.CD  1960  4.430734e+10
# 37962   NY.GDP.MKTP.CD  1961  5.350862e+10
# 65583   NY.GDP.MKTP.CD  1962  6.072302e+10
# 94083   NY.GDP.MKTP.CD  1963  6.949813e+10
# 122866  NY.GDP.MKTP.CD  1964  8.174901e+10

# %%
plt.plot(gdp['Value'])

# %%
child = data[data['IndicatorName']=='Out-of-school children of primary school age, both sexes (number)']

# %%
in2019 = child[child['Year']==2013]
in2019
# Out:
#                                      CountryName CountryCode  \
# 5377790                               Arab World         ARB
# 5378227                   Caribbean small states         CSS
# 5378713           Central Europe and the Baltics         CEB
# 5379274  East Asia & Pacific (all income levels)         EAS
# 5379906    East Asia & Pacific (developing only)         EAP
# ...                                          ...         ...
# 5530397                            Venezuela, RB         VEN
# 5531125                                  Vietnam         VNM
# 5531913                       West Bank and Gaza         WBG
# 5532535                              Yemen, Rep.         YEM
# 5533352                                   Zambia         ZMB
#
#                                              IndicatorName IndicatorCode  \
# 5377790  Out-of-school children of primary school age, ...   SE.PRM.UNER
# 5378227  Out-of-school children of primary school age, ...   SE.PRM.UNER
# ...

# %%
in2019.sort_values(by='Value', ascending=False)
in2019
# Out:
#                                      CountryName CountryCode  \
# 5377790                               Arab World         ARB
# 5378227                   Caribbean small states         CSS
# 5378713           Central Europe and the Baltics         CEB
# 5379274  East Asia & Pacific (all income levels)         EAS
# 5379906    East Asia & Pacific (developing only)         EAP
# ...                                          ...         ...
# 5530397                            Venezuela, RB         VEN
# 5531125                                  Vietnam         VNM
# 5531913                       West Bank and Gaza         WBG
# 5532535                              Yemen, Rep.         YEM
# 5533352                                   Zambia         ZMB
#
#                                              IndicatorName IndicatorCode  \
# 5377790  Out-of-school children of primary school age, ...   SE.PRM.UNER
# 5378227  Out-of-school children of primary school age, ...   SE.PRM.UNER
# ...

# %%
gdp = data[data['IndicatorName']=='GDP at market prices (current US$)']
gdp.rename(columns={"Value": 'gdp'}, inplace = True)
# Out:
# c:\users\parksoyoung\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py:4218: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
merge=pd.merge(child, gdp)
merge
# Out:
# Empty DataFrame
# Columns: [CountryName, CountryCode, IndicatorName, IndicatorCode, Year, Value, gdp]
# Index: []

# %%
child.sort_values(by='Value', ascending=False)
# Out:
#           CountryName CountryCode  \
# 369886          World         WLD
# 438384          World         WLD
# 306912          World         WLD
# 870201          World         WLD
# 508272          World         WLD
# ...               ...         ...
# 1508580     St. Lucia         LCA
# 1106946  Bahamas, The         BHS
# 1596453     St. Lucia         LCA
# 372391   Bahamas, The         BHS
# 650959   Bahamas, The         BHS
#
#                                              IndicatorName IndicatorCode  \
# 369886   Out-of-school children of primary school age, ...   SE.PRM.UNER
# 438384   Out-of-school children of primary school age, ...   SE.PRM.UNER
# 306912   Out-of-school children of primary school age, ...   SE.PRM.UNER
# 870201   Out-of-school children of primary school age, ...   SE.PRM.UNER
# 508272   Out-of-school children of primary school age, ...   SE.PRM.UNER
# ...                                                    ...           ...
# ...

# %%
for i in range(len(child)):
    if child['CountryName'] == 'World':
        child.remove(child[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-5da02a091877> in <module>
#       1 for i in range(len(child)):
# ----> 2     if child['CountryName'] == 'World':
#       3         child.remove(child[i])
#
# c:\users\parksoyoung\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1554             "The truth value of a {0} is ambiguous. "
#    1555             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1556                 self.__class__.__name__
#    1557             )
#    1558         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
