# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import MinMaxScaler
import math
import sklearn.preprocessing as preprocessing
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('Indicators.csv')
data.shape
# Out:
# (5656458, 6)

# %%
rel_columns_7 = ['Adolescent fertility rate (births per 1,000 women ages 15-19)',
 'Age dependency ratio (% of working-age population)',
 'Age dependency ratio, young (% of working-age population)',
 'Birth rate, crude (per 1,000 people)',
 'Fertility rate, total (births per woman)',
 'Life expectancy at birth, female (years)',
 'Life expectancy at birth, male (years)',
 'Life expectancy at birth, total (years)',
 'Mortality rate, adult, female (per 1,000 female adults)',
 'Mortality rate, infant (per 1,000 live births)',
 'Mortality rate, under-5 (per 1,000)',
 'Population, ages 0-14 (% of total)',
 'Population, ages 15-64 (% of total)',
 'Survival to age 65, female (% of cohort)',
 'Survival to age 65, male (% of cohort)',
 'Adjusted net enrolment rate, primary, both sexes (%)',
 'Adjusted net enrolment rate, primary, female (%)',
 'Gross enrolment ratio, secondary, both sexes (%)',
 'Gross enrolment ratio, secondary, female (%)',
 'Gross enrolment ratio, secondary, male (%)',
 'Lower secondary completion rate, both sexes (%)',
 'Net enrolment rate, secondary, both sexes (%)',
 'Net enrolment rate, secondary, female (%)',
 'Net enrolment rate, secondary, male (%)',
 'Primary completion rate, both sexes (%)',
 'Primary completion rate, female (%)',
 'Survival rate to the last grade of primary education, both sexes (%)',
 'Lower secondary completion rate, female (%)',
 'Lower secondary completion rate, male (%)',
 'Survival rate to the last grade of primary education, female (%)',
 'Survival rate to the last grade of primary education, male (%)',
 'Survival rate to Grade 5 of primary education, female (%)',
 'Youth literacy rate, population 15-24 years, both sexes (%)',
 'Youth literacy rate, population 15-24 years, male (%)',
 'Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)',
 'Wanted fertility rate (births per woman)',
 'Access to electricity (% of population)',
 'Access to electricity, rural (% of rural population)',
 'Improved sanitation facilities (% of population with access)',
 'Improved sanitation facilities, rural (% of rural population with access)',
 'Improved sanitation facilities, urban (% of urban population with access)',
 'Improved water source (% of population with access)',
 'Improved water source, rural (% of rural population with access)',
 'Lifetime risk of maternal death (%)',
 'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
 'Mortality rate, infant, female (per 1,000 live births)',
 'Mortality rate, infant, male (per 1,000 live births)',
 'Mortality rate, neonatal (per 1,000 live births)',
 'Mortality rate, under-5, female (per 1,000 live births)',
 'Mortality rate, under-5, male (per 1,000 live births)',
 'Prevalence of anemia among children (% of children under 5)',
 'Prevalence of anemia among pregnant women (%)',
 'Renewable energy consumption (% of total final energy consumption)',
 'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)',
 'Cause of death, by non-communicable diseases (% of total)',
 'Survey mean consumption or income per capita, bottom 40% of population (2005 PPP $ per day)',
 'Survey mean consumption or income per capita, total population (2005 PPP $ per day)']

# %%
data[data['IndicatorName']== 'Lower secondary completion rate, both sexes (%)']
# Out:
#                                       CountryName CountryCode  \
# 297747                                 Arab World         ARB
# 297955                     Caribbean small states         CSS
# 298115             Central Europe and the Baltics         CEB
# 299945   Fragile and conflict affected situations         FCS
# 300170     Heavily indebted poor countries (HIPC)         HPC
# ...                                           ...         ...
# 5612532                                     Palau         PLW
# 5619408                     Sao Tome and Principe         STP
# 5619929                              Saudi Arabia         SAU
# 5620455                                   Senegal         SEN
# 5630316                                Tajikistan         TJK
#
#                                            IndicatorName      IndicatorCode  \
# 297747   Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 297955   Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 298115   Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 299945   Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 300170   Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# ...                                                  ...                ...
# 5612532  Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 5619408  Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 5619929  Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 5620455  Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 5630316  Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
#
#          Year       Value
# 297747   1970   28.576332
# 297955   1970   61.215279
# 298115   1970   87.651901
# 299945   1970   23.388626
# 300170   1970   17.481548
# ...       ...         ...
# 5612532  2014  104.761902
# 5619408  2014   66.910873
# 5619929  2014  114.355873
# 5620455  2014   41.200150
# 5630316  2014   93.338654
#
# [4392 rows x 6 columns]

# %%
for i in rel_columns_7:
    if len(data[data['IndicatorName']==i]) < 500:
        rel_columns_7.remove(i)

len(rel_columns_7)
# Out:
# 54

# %%
rel_columns_8 = ['Adolescent fertility rate (births per 1,000 women ages 15-19)',
 'Birth rate, crude (per 1,000 people)',
 'Net enrolment rate, secondary, both sexes (%)',
 'Net enrolment rate, secondary, female (%)',
 'Net enrolment rate, secondary, male (%)',
 'Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)',
 'Mortality rate, under-5, female (per 1,000 live births)',
 'Mortality rate, under-5, male (per 1,000 live births)',
 'Prevalence of anemia among children (% of children under 5)',
 'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)',
 'Cause of death, by non-communicable diseases (% of total)',
 'Survey mean consumption or income per capita, bottom 40% of population (2005 PPP $ per day)',
 'Survey mean consumption or income per capita, total population (2005 PPP $ per day)']

# %%
# 여기서부터 관련도 높은 feature 뽑는 것
target_id = 'Adolescent fertility rate (births per 1,000 women ages 15-19)';

target = data[data['IndicatorName']==target_id]

# %%
# 해당하는 indicator해서 그 데이터 프레임 사용하기 편하게 바꿔주는거 
def transformDf(data, ind):
    data2000=data[(data['Year'] >= 2000) & (data['Year'] < 2015) ]
    col8 = data2000[(data2000['IndicatorName'].isin(ind))]
    col8=col8.reset_index(drop=True)
    
    name_list = list()

    for i in col8.index:
        name_list.append( col8.loc[i,'CountryName'] + "_" + str(col8.loc[i,'Year']))
    col8["name"] = name_list
    col8=col8.pivot_table(values="Value",index="name",columns="IndicatorName")
    return col8

# %%
df=transformDf(data,rel_columns_8)
df=df.dropna(subset=[target_id])
df.head()
# Out:
# IndicatorName     Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# name
# Afghanistan_2000                                           153.8456
# Afghanistan_2001                                           150.0468
# Afghanistan_2002                                           146.2480
# Afghanistan_2003                                           140.4764
# Afghanistan_2004                                           134.7048
#
# IndicatorName     Birth rate, crude (per 1,000 people)  \
# name
# Afghanistan_2000                                48.332
# Afghanistan_2001                                47.835
# Afghanistan_2002                                47.230
# Afghanistan_2003                                46.538
# Afghanistan_2004                                45.761
#
# IndicatorName     Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)  \
# name
# Afghanistan_2000                                               60.5
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Cause of death, by non-communicable diseases (% of total)  \
# name
# Afghanistan_2000                                               26.4
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Mortality rate, under-5, female (per 1,000 live births)  \
# name
# Afghanistan_2000                                              132.7
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Mortality rate, under-5, male (per 1,000 live births)  \
# name
# Afghanistan_2000                                              141.1
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Net enrolment rate, secondary, both sexes (%)  \
# name
# Afghanistan_2000                                            NaN
# Afghanistan_2001                                            NaN
# Afghanistan_2002                                            NaN
# Afghanistan_2003                                            NaN
# Afghanistan_2004                                            NaN
#
# IndicatorName     Net enrolment rate, secondary, female (%)  \
# name
# Afghanistan_2000                                        NaN
# Afghanistan_2001                                        NaN
# Afghanistan_2002                                        NaN
# Afghanistan_2003                                        NaN
# Afghanistan_2004                                        NaN
#
# IndicatorName     Net enrolment rate, secondary, male (%)  \
# name
# Afghanistan_2000                                      NaN
# Afghanistan_2001                                      NaN
# Afghanistan_2002                                      NaN
# Afghanistan_2003                                      NaN
# Afghanistan_2004                                      NaN
#
# IndicatorName     Prevalence of anemia among children (% of children under 5)  \
# name
# Afghanistan_2000                                               46.8
# Afghanistan_2001                                               45.4
# Afghanistan_2002                                               44.2
# Afghanistan_2003                                               43.3
# Afghanistan_2004                                               42.4
#
# IndicatorName     Survey mean consumption or income per capita, bottom 40% of population (2005 PPP $ per day)  \
# name
# Afghanistan_2000                                                NaN
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Survey mean consumption or income per capita, total population (2005 PPP $ per day)  \
# name
# Afghanistan_2000                                                NaN
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)
# name
# Afghanistan_2000                                                NaN
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN

# %%
df.columns
# Out:
# Index(['Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Birth rate, crude (per 1,000 people)',
#        'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)',
#        'Cause of death, by non-communicable diseases (% of total)',
#        'Mortality rate, under-5, female (per 1,000 live births)',
#        'Mortality rate, under-5, male (per 1,000 live births)',
#        'Net enrolment rate, secondary, both sexes (%)',
#        'Net enrolment rate, secondary, female (%)',
#        'Net enrolment rate, secondary, male (%)',
#        'Prevalence of anemia among children (% of children under 5)',
#        'Survey mean consumption or income per capita, bottom 40% of population (2005 PPP $ per day)',
#        'Survey mean consumption or income per capita, total population (2005 PPP $ per day)',
#        'Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)'],
#       dtype='object', name='IndicatorName')

# %%
data[data['IndicatorName']=='Lower secondary completion rate, both sexes (%)']
# Out:
#                                       CountryName CountryCode  \
# 297747                                 Arab World         ARB
# 297955                     Caribbean small states         CSS
# 298115             Central Europe and the Baltics         CEB
# 299945   Fragile and conflict affected situations         FCS
# 300170     Heavily indebted poor countries (HIPC)         HPC
# ...                                           ...         ...
# 5612532                                     Palau         PLW
# 5619408                     Sao Tome and Principe         STP
# 5619929                              Saudi Arabia         SAU
# 5620455                                   Senegal         SEN
# 5630316                                Tajikistan         TJK
#
#                                            IndicatorName      IndicatorCode  \
# 297747   Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 297955   Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 298115   Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 299945   Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 300170   Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# ...                                                  ...                ...
# 5612532  Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 5619408  Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 5619929  Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 5620455  Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
# 5630316  Lower secondary completion rate, both sexes (%)  SE.SEC.CMPT.LO.ZS
#
#          Year       Value
# 297747   1970   28.576332
# 297955   1970   61.215279
# 298115   1970   87.651901
# 299945   1970   23.388626
# 300170   1970   17.481548
# ...       ...         ...
# 5612532  2014  104.761902
# 5619408  2014   66.910873
# 5619929  2014  114.355873
# 5620455  2014   41.200150
# 5630316  2014   93.338654
#
# [4392 rows x 6 columns]

# %%
df.head()
# Out:
# IndicatorName     Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# name
# Afghanistan_2000                                           153.8456
# Afghanistan_2001                                           150.0468
# Afghanistan_2002                                           146.2480
# Afghanistan_2003                                           140.4764
# Afghanistan_2004                                           134.7048
#
# IndicatorName     Birth rate, crude (per 1,000 people)  \
# name
# Afghanistan_2000                                48.332
# Afghanistan_2001                                47.835
# Afghanistan_2002                                47.230
# Afghanistan_2003                                46.538
# Afghanistan_2004                                45.761
#
# IndicatorName     Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)  \
# name
# Afghanistan_2000                                               60.5
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Cause of death, by non-communicable diseases (% of total)  \
# name
# Afghanistan_2000                                               26.4
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Mortality rate, under-5, female (per 1,000 live births)  \
# name
# Afghanistan_2000                                              132.7
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Mortality rate, under-5, male (per 1,000 live births)  \
# name
# Afghanistan_2000                                              141.1
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Net enrolment rate, secondary, both sexes (%)  \
# name
# Afghanistan_2000                                            NaN
# Afghanistan_2001                                            NaN
# Afghanistan_2002                                            NaN
# Afghanistan_2003                                            NaN
# Afghanistan_2004                                            NaN
#
# IndicatorName     Net enrolment rate, secondary, female (%)  \
# name
# Afghanistan_2000                                        NaN
# Afghanistan_2001                                        NaN
# Afghanistan_2002                                        NaN
# Afghanistan_2003                                        NaN
# Afghanistan_2004                                        NaN
#
# IndicatorName     Net enrolment rate, secondary, male (%)  \
# name
# Afghanistan_2000                                      NaN
# Afghanistan_2001                                      NaN
# Afghanistan_2002                                      NaN
# Afghanistan_2003                                      NaN
# Afghanistan_2004                                      NaN
#
# IndicatorName     Prevalence of anemia among children (% of children under 5)  \
# name
# Afghanistan_2000                                               46.8
# Afghanistan_2001                                               45.4
# Afghanistan_2002                                               44.2
# Afghanistan_2003                                               43.3
# Afghanistan_2004                                               42.4
#
# IndicatorName     Survey mean consumption or income per capita, bottom 40% of population (2005 PPP $ per day)  \
# name
# Afghanistan_2000                                                NaN
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Survey mean consumption or income per capita, total population (2005 PPP $ per day)  \
# name
# Afghanistan_2000                                                NaN
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)
# name
# Afghanistan_2000                                                NaN
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN

# %%
merged = data[data['IndicatorName']==target_id]

for i in rel_columns_8:
    target = data[data['IndicatorName']==i]
    target.rename(columns={"Value": i}, inplace = True)
    target=target.drop(columns=['IndicatorCode', 'IndicatorName', 'CountryName'])
#    print(target.head())
    merged_bef = merged
    merged = pd.merge(merged, target)
    if len(merged) < 500:
        merged = merged_bef
#    print(merged.head())

merged

# %%
merged = data[data['IndicatorName']==target_id]

for i in rel_columns_7:
    target = data[data['IndicatorName']==i]
    target.rename(columns={"Value": i}, inplace = True)
    target=target.drop(columns=['IndicatorCode', 'IndicatorName', 'CountryName'])
#    print(target.head())
    merged_bef = merged
    merged = pd.merge(merged, target)
    if len(merged) < 200:
        merged = merged_bef
#    print(merged.head())

merged
# Out:
#        CountryName CountryCode  \
# 0         Botswana         BWA
# 1           Guinea         GIN
# 2            Niger         NER
# 3         Botswana         BWA
# 4       Costa Rica         CRI
# ..             ...         ...
# 369           Peru         PER
# 370          Samoa         WSM
# 371      Sri Lanka         LKA
# 372         Turkey         TUR
# 373  Venezuela, RB         VEN
#
#                                          IndicatorName IndicatorCode  Year  \
# 0    Adolescent fertility rate (births per 1,000 wo...   SP.ADO.TFRT  1990
# 1    Adolescent fertility rate (births per 1,000 wo...   SP.ADO.TFRT  1990
# 2    Adolescent fertility rate (births per 1,000 wo...   SP.ADO.TFRT  1990
# 3    Adolescent fertility rate (births per 1,000 wo...   SP.ADO.TFRT  1991
# 4    Adolescent fertility rate (births per 1,000 wo...   SP.ADO.TFRT  1991
# ..                                                 ...           ...   ...
# 369  Adolescent fertility rate (births per 1,000 wo...   SP.ADO.TFRT  2011
# 370  Adolescent fertility rate (births per 1,000 wo...   SP.ADO.TFRT  2011
# 371  Adolescent fertility rate (births per 1,000 wo...   SP.ADO.TFRT  2011
# 372  Adolescent fertility rate (births per 1,000 wo...   SP.ADO.TFRT  2011
# 373  Adolescent fertility rate (births per 1,000 wo...   SP.ADO.TFRT  2011
#
#         Value  Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0    102.0524                                           102.0524
# 1    180.7146                                           180.7146
# 2    222.2130                                           222.2130
# 3     93.6652                                            93.6652
# 4     92.4632                                            92.4632
# ..        ...                                                ...
# 369   52.6508                                            52.6508
# 370   28.9356                                            28.9356
# 371   18.6794                                            18.6794
# 372   33.2360                                            33.2360
# 373   81.2292                                            81.2292
#
#      Age dependency ratio (% of working-age population)  \
# 0                                            89.996571
# 1                                            89.617082
# 2                                           100.023714
# 3                                            88.163978
# 4                                            65.942106
# ..                                                 ...
# 369                                          54.610755
# 370                                          76.353697
# 371                                          49.204133
# 372                                          50.919713
# 373                                          53.799102
#
#      Age dependency ratio, young (% of working-age population)  \
# 0                                            85.008764
# 1                                            83.059669
# 2                                            95.353577
# 3                                            83.176254
# 4                                            58.011655
# ..                                                 ...
# 369                                          44.858755
# 370                                          67.388011
# 371                                          37.746744
# 372                                          40.188071
# 373                                          45.119864
#
#      Birth rate, crude (per 1,000 people)  ...  \
# 0                                  34.509  ...
# 1                                  46.505  ...
# 2                                  55.122  ...
# 3                                  33.498  ...
# 4                                  25.984  ...
# ..                                    ...  ...
# 369                                20.674  ...
# 370                                27.372  ...
# 371                                18.332  ...
# 372                                17.439  ...
# 373                                20.407  ...
#
#      Improved sanitation facilities, rural (% of rural population with access)  \
# 0                                                 22.9
# 1                                                  4.7
# 2                                                  1.2
# 3                                                 23.8
# 4                                                 83.1
# ..                                                 ...
# 369                                               46.9
# 370                                               91.2
# 371                                               93.9
# 372                                               81.9
# 373                                               67.7
#
#      Improved sanitation facilities, urban (% of urban population with access)  \
# 0                                                 62.0
# 1                                                 17.6
# 2                                                 18.9
# 3                                                 62.7
# 4                                                 94.2
# ..                                                 ...
# 369                                               80.5
# 370                                               93.4
# 371                                               87.5
# 372                                               97.9
# 373                                               96.7
#
#      Improved water source (% of population with access)  \
# 0                                                 92.2
# 1                                                 52.4
# 2                                                 33.7
# 3                                                 92.8
# 4                                                 93.1
# ..                                                 ...
# 369                                               85.0
# 370                                               98.1
# 371                                               92.2
# 372                                               99.1
# 373                                               92.8
#
#      Improved water source, rural (% of rural population with access)  \
# 0                                                 86.9
# 1                                                 39.1
# 2                                                 28.8
# 3                                                 87.1
# 4                                                 86.7
# ..                                                 ...
# 369                                               65.2
# 370                                               98.3
# 371                                               90.9
# 372                                               97.0
# 373                                               77.0
#
#      Lifetime risk of maternal death (%)  \
# 0                               1.196932
# 1                               7.033457
# 2                               6.785329
# 3                               1.099415
# 4                               0.160381
# ..                                   ...
# 369                             0.225438
# 370                             0.256360
# 371                             0.074984
# 372                             0.046433
# 373                             0.258385
#
#      Maternal mortality ratio (modeled estimate, per 100,000 live births)  \
# 0                                                243.0
# 1                                               1040.0
# 2                                                873.0
# 3                                                233.0
# 4                                                 45.0
# ..                                                 ...
# 369                                               85.0
# 370                                               61.0
# 371                                               33.0
# 372                                               21.0
# 373                                               99.0
#
#      Mortality rate, neonatal (per 1,000 live births)  \
# 0                                                25.9
# 1                                                62.9
# 2                                                54.5
# 3                                                25.7
# 4                                                 8.8
# ..                                                ...
# 369                                               9.8
# 370                                              10.1
# 371                                               6.1
# 372                                               9.3
# 373                                               9.9
#
#      Prevalence of anemia among children (% of children under 5)  \
# 0                                                 47.0
# 1                                                 82.9
# 2                                                 87.2
# 3                                                 46.0
# 4                                                 27.5
# ..                                                 ...
# 369                                               33.2
# 370                                               32.0
# 371                                               36.1
# 372                                               30.1
# 373                                               32.0
#
#      Prevalence of anemia among pregnant women (%)  \
# 0                                             40.5
# 1                                             63.6
# 2                                             63.0
# 3                                             39.8
# 4                                             32.2
# ..                                             ...
# 369                                           23.0
# 370                                           26.2
# 371                                           25.5
# 372                                           27.8
# 373                                           26.9
#
#      Renewable energy consumption (% of total final energy consumption)
# 0                                            47.584663
# 1                                            92.593984
# 2                                            86.715259
# 3                                            48.082742
# 4                                            44.695587
# ..                                                 ...
# 369                                          29.547259
# 370                                          23.152074
# 371                                          59.462528
# 372                                          12.793322
# 373                                          12.356260
#
# [374 rows x 49 columns]

# %%
# 기준: value 등급? 만듦
print(min(merged['Value']))
print(max(merged['Value']))
print(merged['Value'].mean())
# Out:
# 2.093
# 222.324
# 72.10240748663102

# %%
def make_grade(merged, k):
    min_value = min(merged[target_id])
    max_value = max(merged[target_id])
    value=(max_value-min_value)/k
    for i in range(k):
        for j in merged.index:
            if merged.loc[j, target_id] >= min_value + value*i and merged.loc[j, target_id] <= min_value + value*(i+1):
                merged.loc[j, 'grade'] = i
    return merged

# %%
make_grade(df, 5)
# Out:
# IndicatorName     Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# name
# Afghanistan_2000                                           153.8456
# Afghanistan_2001                                           150.0468
# Afghanistan_2002                                           146.2480
# Afghanistan_2003                                           140.4764
# Afghanistan_2004                                           134.7048
# ...                                                             ...
# Zimbabwe_2010                                              115.0006
# Zimbabwe_2011                                              114.1658
# Zimbabwe_2012                                              113.3310
# Zimbabwe_2013                                              111.8664
# Zimbabwe_2014                                              110.4018
#
# IndicatorName     Birth rate, crude (per 1,000 people)  \
# name
# Afghanistan_2000                                48.332
# Afghanistan_2001                                47.835
# Afghanistan_2002                                47.230
# Afghanistan_2003                                46.538
# Afghanistan_2004                                45.761
# ...                                                ...
# Zimbabwe_2010                                   36.267
# Zimbabwe_2011                                   36.264
# Zimbabwe_2012                                   36.077
# Zimbabwe_2013                                   35.715
# Zimbabwe_2014                                      NaN
#
# IndicatorName     Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)  \
# name
# Afghanistan_2000                                               60.5
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
# ...                                                             ...
# Zimbabwe_2010                                                   NaN
# Zimbabwe_2011                                                   NaN
# Zimbabwe_2012                                                  61.5
# Zimbabwe_2013                                                   NaN
# Zimbabwe_2014                                                   NaN
#
# IndicatorName     Cause of death, by non-communicable diseases (% of total)  \
# name
# Afghanistan_2000                                               26.4
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
# ...                                                             ...
# Zimbabwe_2010                                                   NaN
# Zimbabwe_2011                                                   NaN
# Zimbabwe_2012                                                  30.5
# Zimbabwe_2013                                                   NaN
# Zimbabwe_2014                                                   NaN
#
# IndicatorName     Mortality rate, under-5, female (per 1,000 live births)  \
# name
# Afghanistan_2000                                              132.7
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
# ...                                                             ...
# Zimbabwe_2010                                                  83.0
# Zimbabwe_2011                                                   NaN
# Zimbabwe_2012                                                   NaN
# Zimbabwe_2013                                                   NaN
# Zimbabwe_2014                                                   NaN
#
# IndicatorName     Mortality rate, under-5, male (per 1,000 live births)  \
# name
# Afghanistan_2000                                              141.1
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
# ...                                                             ...
# Zimbabwe_2010                                                  95.7
# Zimbabwe_2011                                                   NaN
# Zimbabwe_2012                                                   NaN
# Zimbabwe_2013                                                   NaN
# Zimbabwe_2014                                                   NaN
#
# IndicatorName     Net enrolment rate, secondary, both sexes (%)  \
# name
# Afghanistan_2000                                            NaN
# Afghanistan_2001                                            NaN
# Afghanistan_2002                                            NaN
# Afghanistan_2003                                            NaN
# Afghanistan_2004                                            NaN
# ...                                                         ...
# Zimbabwe_2010                                               NaN
# Zimbabwe_2011                                               NaN
# Zimbabwe_2012                                          43.83839
# Zimbabwe_2013                                               NaN
# Zimbabwe_2014                                               NaN
#
# IndicatorName     Net enrolment rate, secondary, female (%)  \
# name
# Afghanistan_2000                                        NaN
# Afghanistan_2001                                        NaN
# Afghanistan_2002                                        NaN
# Afghanistan_2003                                        NaN
# Afghanistan_2004                                        NaN
# ...                                                     ...
# Zimbabwe_2010                                           NaN
# Zimbabwe_2011                                           NaN
# Zimbabwe_2012                                     43.970421
# Zimbabwe_2013                                           NaN
# Zimbabwe_2014                                           NaN
#
# IndicatorName     Net enrolment rate, secondary, male (%)  \
# name
# Afghanistan_2000                                      NaN
# Afghanistan_2001                                      NaN
# Afghanistan_2002                                      NaN
# Afghanistan_2003                                      NaN
# Afghanistan_2004                                      NaN
# ...                                                   ...
# Zimbabwe_2010                                         NaN
# Zimbabwe_2011                                         NaN
# Zimbabwe_2012                                   43.706322
# Zimbabwe_2013                                         NaN
# Zimbabwe_2014                                         NaN
#
# IndicatorName     Prevalence of anemia among children (% of children under 5)  \
# name
# Afghanistan_2000                                               46.8
# Afghanistan_2001                                               45.4
# Afghanistan_2002                                               44.2
# Afghanistan_2003                                               43.3
# Afghanistan_2004                                               42.4
# ...                                                             ...
# Zimbabwe_2010                                                  58.4
# Zimbabwe_2011                                                  59.0
# Zimbabwe_2012                                                   NaN
# Zimbabwe_2013                                                   NaN
# Zimbabwe_2014                                                   NaN
#
# IndicatorName     Survey mean consumption or income per capita, bottom 40% of population (2005 PPP $ per day)  \
# name
# Afghanistan_2000                                                NaN
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
# ...                                                             ...
# Zimbabwe_2010                                                   NaN
# Zimbabwe_2011                                                   NaN
# Zimbabwe_2012                                                   NaN
# Zimbabwe_2013                                                   NaN
# Zimbabwe_2014                                                   NaN
#
# IndicatorName     Survey mean consumption or income per capita, total population (2005 PPP $ per day)  \
# name
# Afghanistan_2000                                                NaN
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
# ...                                                             ...
# Zimbabwe_2010                                                   NaN
# Zimbabwe_2011                                                   NaN
# Zimbabwe_2012                                                   NaN
# Zimbabwe_2013                                                   NaN
# Zimbabwe_2014                                                   NaN
#
# IndicatorName     Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)  \
# name
# Afghanistan_2000                                                NaN
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
# ...                                                             ...
# Zimbabwe_2010                                                   NaN
# Zimbabwe_2011                                                  23.5
# Zimbabwe_2012                                                   NaN
# Zimbabwe_2013                                                   NaN
# Zimbabwe_2014                                                   NaN
#
# IndicatorName     grade
# name
# Afghanistan_2000    3.0
# Afghanistan_2001    3.0
# Afghanistan_2002    3.0
# Afghanistan_2003    3.0
# Afghanistan_2004    3.0
# ...                 ...
# Zimbabwe_2010       2.0
# Zimbabwe_2011       2.0
# Zimbabwe_2012       2.0
# Zimbabwe_2013       2.0
# Zimbabwe_2014       2.0
#
# [3405 rows x 14 columns]

# %%
# label encode categorical data
def labelEncode():
    for i in merged.columns:
        le = preprocessing.LabelEncoder()
        le.fit(merged[i])
        merged[i]= le.transform(merged[i])

# %%
# label encode categorical data (array)
def labelEncode_arr(y):
    '''
    label encoding array
    return value: label encoded array
    '''
    le = preprocessing.LabelEncoder()
    le.fit(y)
    y= le.transform(y)
    return y

# %%
# scaling data (MinMaxScaler)
def minmax(X):
    scaler = preprocessing.MinMaxScaler()
    fit = scaler.fit(X)

    X_scaled = scaler.transform(X)
    X_scaled = pd.DataFrame(X_scaled, columns=X.columns, index=list(X.index.values))
    return X_scaled

# %%
# scaling data (MinMaxScaler)
def standard(X):
    scaler = preprocessing.StandardScaler()
    fit = scaler.fit(X)

    X_scaled = scaler.transform(X)
    X_scaled = pd.DataFrame(X_scaled, columns=X.columns, index=list(X.index.values))
    return X_scaled

# %%
# cleansing dataset
def cleansing(X):
    # cleansing missing data
    X.dropna(axis=0, thresh=1, inplace=True)
    # cleansing outliers
    robust = preprocessing.RobustScaler().fit(X)

    X_robust = robust.transform(X)
    X_robust = pd.DataFrame(X, columns=X.columns, index=list(X.index.values))
    return X_robust

# %%
def fillnaX(X):
    for i in X.columns:
        df[i] = df[i].fillna(df[i].mean())
    return X

# %%
eps=[0.001, 0.002, 0.005, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5 ]
min_samples=[ 3, 5, 10, 15, 20, 30, 50, 100 ]
dis_measure = ['euclidean', 'hamming']

# %%
eps=[10, 20, 30, 40, 50 ]
min_samples=[ 3, 5, 10, 15, 20, 30, 50, 100 ]
dis_measure = ['euclidean', 'hamming']

# %%
def purity_score(y, y_label):
    print('y', y)
    print('label', y_label)
    unique_labels=set(y_label)
    
    sum_=0
    
    purity = pd.DataFrame(0, index=np.arange(len(unique_labels)), columns=["0", "1"])
#    print(purity)
    for i in range(len(y_label)):
        if y[i] ==0:
            purity.iloc[y_label[i], 0] = purity.iloc[y_label[i], 0]+1
        else:
            purity.iloc[y_label[i], 1] = purity.iloc[y_label[i], 1]+1

    for j in range(len(purity)):
        if purity.iloc[j, 0] > purity.iloc[j, 1]:
            sum_=sum_ + purity.iloc[j, 0]
        else:
            sum_=sum_ + purity.iloc[j, 1]
    
    return sum_/len(y)

# %%
def none(i, j, n):
    '''
    X=merged.drop(columns=['grade'])
    y=merged['grade']
    '''
    X=df.drop(columns=[target_id])
    y=df[target_id]
    
    X = cleansing(X)
    X= fillnaX(X)

    db = DBSCAN(eps = i, min_samples = j, metric= n).fit(X) 

    cluster_labels = db.labels_
    n_clusters = len(set(cluster_labels))
    
    print('clusters', n_clusters)
    print(purity_score(y, cluster_labels))

# %%
merged = merged.drop(columns=['CountryCode', 'IndicatorCode'])

# %%
df.head()
# Out:
# IndicatorName     Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# name
# Afghanistan_2000                                           153.8456
# Afghanistan_2001                                           150.0468
# Afghanistan_2002                                           146.2480
# Afghanistan_2003                                           140.4764
# Afghanistan_2004                                           134.7048
#
# IndicatorName     Birth rate, crude (per 1,000 people)  \
# name
# Afghanistan_2000                                48.332
# Afghanistan_2001                                47.835
# Afghanistan_2002                                47.230
# Afghanistan_2003                                46.538
# Afghanistan_2004                                45.761
#
# IndicatorName     Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)  \
# name
# Afghanistan_2000                                               60.5
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Cause of death, by non-communicable diseases (% of total)  \
# name
# Afghanistan_2000                                               26.4
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Mortality rate, under-5, female (per 1,000 live births)  \
# name
# Afghanistan_2000                                              132.7
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Mortality rate, under-5, male (per 1,000 live births)  \
# name
# Afghanistan_2000                                              141.1
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Net enrolment rate, secondary, both sexes (%)  \
# name
# Afghanistan_2000                                            NaN
# Afghanistan_2001                                            NaN
# Afghanistan_2002                                            NaN
# Afghanistan_2003                                            NaN
# Afghanistan_2004                                            NaN
#
# IndicatorName     Net enrolment rate, secondary, female (%)  \
# name
# Afghanistan_2000                                        NaN
# Afghanistan_2001                                        NaN
# Afghanistan_2002                                        NaN
# Afghanistan_2003                                        NaN
# Afghanistan_2004                                        NaN
#
# IndicatorName     Net enrolment rate, secondary, male (%)  \
# name
# Afghanistan_2000                                      NaN
# Afghanistan_2001                                      NaN
# Afghanistan_2002                                      NaN
# Afghanistan_2003                                      NaN
# Afghanistan_2004                                      NaN
#
# IndicatorName     Prevalence of anemia among children (% of children under 5)  \
# name
# Afghanistan_2000                                               46.8
# Afghanistan_2001                                               45.4
# Afghanistan_2002                                               44.2
# Afghanistan_2003                                               43.3
# Afghanistan_2004                                               42.4
#
# IndicatorName     Survey mean consumption or income per capita, bottom 40% of population (2005 PPP $ per day)  \
# name
# Afghanistan_2000                                                NaN
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Survey mean consumption or income per capita, total population (2005 PPP $ per day)  \
# name
# Afghanistan_2000                                                NaN
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)  \
# name
# Afghanistan_2000                                                NaN
# Afghanistan_2001                                                NaN
# Afghanistan_2002                                                NaN
# Afghanistan_2003                                                NaN
# Afghanistan_2004                                                NaN
#
# IndicatorName     grade
# name
# Afghanistan_2000    3.0
# Afghanistan_2001    3.0
# Afghanistan_2002    3.0
# Afghanistan_2003    3.0
# Afghanistan_2004    3.0

# %%
def labeling(i, j, n):
    
    '''
    merged['CountryName']= labelEncode_arr(merged['CountryName'])
    merged['IndicatorName']= labelEncode_arr(merged['IndicatorName'])
    
    '''
    X=df.drop(columns=[target_id])
    y=df[target_id]


    X = cleansing(X)
    X= fillnaX(X)

    db = DBSCAN(eps = i, min_samples = j, metric= n).fit(X) 

    cluster_labels = db.labels_
    n_clusters = len(set(cluster_labels))
    make_grade(df, n_clusters)
    
    print('clusters', n_clusters)
    print(purity_score(y, cluster_labels))
    
    if (n_clusters >= 2):
        print('valid')

# %%
def label_minmax(i, j, n):
    '''
    merged['CountryName']= labelEncode_arr(merged['CountryName'])
    merged['IndicatorName']= labelEncode_arr(merged['IndicatorName'])
    
    '''
    
    X=df.drop(columns=[target_id])
    y=df[target_id]

    X_scaled = minmax(X)
    X_scaled = cleansing(X_scaled)
    X_scaled = fillnaX(X_scaled)

    
    db = DBSCAN(eps = i, min_samples = j, metric= n).fit(X_scaled) 

    cluster_labels = db.labels_
    n_clusters = len(set(cluster_labels))
    make_grade(df, n_clusters)
    
    print('clusters', n_clusters)
    print(purity_score(y, cluster_labels))
    
    if (n_clusters >= 2):
        print('valid')

# %%
def label_standard(i, j, n):
    '''
    merged['CountryName']= labelEncode_arr(merged['CountryName'])
    merged['IndicatorName']= labelEncode_arr(merged['IndicatorName'])

    '''

    X=df.drop(columns=[target_id])
    y=df[target_id]
        
    X_scaled = standard(X)
    X_scaled = cleansing(X_scaled)
    X_scaled = fillnaX(X_scaled)
    
    db = DBSCAN(eps = i, min_samples = j, metric= n).fit(X_scaled) 

    cluster_labels = db.labels_
    n_clusters = len(set(cluster_labels))
    make_grade(df, n_clusters)
    
    print('clusters', n_clusters)
    print(purity_score(y, cluster_labels))

    if (n_clusters >= 2):
        print('valid')

# %%
for i in eps:
    for j in min_samples:
        for n in dis_measure:
            print(i, j, n)
            # varying preprocessing            

            # none
            if n == 'hamming':
                print('none')
                none(i, j, n)
            
            # labelEncoding
            print('\nlabelEncoding')
            labeling(i, j, n)
            
            # labelEncoding + MinMaxScaler
            print('\nlabelEncoding + MinMaxScaler')
            label_minmax(i, j, n)
            
            # labelEncoding + StandardScaler
            print('\nlabelEncoding + StandardScaler')
            label_standard(i, j, n)
            print('\n')
# Out:
# 10 3 euclidean
#
# labelEncoding
# clusters 26
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [-1  0  0 ...  9  0  0]
# 1.0
# valid
#
# labelEncoding + MinMaxScaler
# clusters 1
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [0 0 0 ... 0 0 0]
# 1.0
#
# labelEncoding + StandardScaler
# clusters 3
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [0 0 0 ... 0 0 0]
# 1.0
# valid
#
#
# 10 3 hamming
# none
# clusters 1
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [0 0 0 ... 0 0 0]
# 1.0
#
# labelEncoding
# clusters 1
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [0 0 0 ... 0 0 0]
# 1.0
#
# labelEncoding + MinMaxScaler
# clusters 1
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [0 0 0 ... 0 0 0]
# 1.0
#
# labelEncoding + StandardScaler
# clusters 1
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [0 0 0 ... 0 0 0]
# 1.0
#
#
# 10 5 euclidean
#
# labelEncoding
# clusters 12
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [-1  0  0 ...  7  0  0]
# 1.0
# valid
#
# labelEncoding + MinMaxScaler
# clusters 1
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [0 0 0 ... 0 0 0]
# 1.0
#
# labelEncoding + StandardScaler
# clusters 3
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [0 0 0 ... 0 0 0]
# 1.0
# valid
#
#
# 10 5 hamming
# none
# clusters 1
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [0 0 0 ... 0 0 0]
# 1.0
#
# labelEncoding
# clusters 1
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [0 0 0 ... 0 0 0]
# 1.0
#
# labelEncoding + MinMaxScaler
# clusters 1
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [0 0 0 ... 0 0 0]
# 1.0
#
# labelEncoding + StandardScaler
# clusters 1
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [0 0 0 ... 0 0 0]
# 1.0
#
#
# 10 10 euclidean
#
# labelEncoding
# clusters 7
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [-1  0  0 ... -1  0  0]
# 1.0
# valid
#
# labelEncoding + MinMaxScaler
# clusters 1
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [0 0 0 ... 0 0 0]
# 1.0
#
# labelEncoding + StandardScaler
# clusters 2
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [0 0 0 ... 0 0 0]
# 1.0
# valid
#
#
# 10 10 hamming
# none
# clusters 1
# y name
# Afghanistan_2000    153.8456
# Afghanistan_2001    150.0468
# Afghanistan_2002    146.2480
# Afghanistan_2003    140.4764
# Afghanistan_2004    134.7048
#                       ...
# Zimbabwe_2010       115.0006
# Zimbabwe_2011       114.1658
# Zimbabwe_2012       113.3310
# Zimbabwe_2013       111.8664
# Zimbabwe_2014       110.4018
# Name: Adolescent fertility rate (births per 1,000 women ages 15-19), Length: 3405, dtype: float64
# label [0 0 0 ... 0 0 0]
# 1.0
#
# labelEncoding
