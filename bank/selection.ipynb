# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("data/bank-additional-full.csv",sep=";")
y=data.iloc[:,-1]
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
print(y.value_counts())
# Out:
# no     36548
# yes     4640
# Name: y, dtype: int64

# %%
va=data['job'].values
print(len(va.unqiue()))
te=data[['job','y']]
temp=te.groupby('job')['y'].value_counts()
print(temp)
"""for i in range(len(va)):
    
    print(temp[va[i]]['no'] /temp[va[i]].sum())
    print(temp[va[i]]['yes'] /temp[va[i]].sum())

print(temp)
#k['no']=k['no']/y.value_counts()[0]
#k['yes']=k['yes']/y.value_counts()[0]
"""
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-a9b68289aa3e> in <module>
#       1 va=data['job'].values
# ----> 2 print(len(va.unqiue()))
#       3 te=data[['job','y']]
#       4 temp=te.groupby('job')['y'].value_counts()
#       5 print(temp)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'unqiue'

# %%
object_feature = [col for col in data.columns if data[col].dtypes == 'object' ]

for i in object_feature:
    te=data.groupby('y')[i].value_counts()
    print("<no>")
    print(te['no']/y.value_counts()[0])
    print("\n <yes>")
    print(te['yes']/y.value_counts()[1])
    
    print("----\n\n")
# Out:
# <no>
# job
# admin.           0.248167
# blue-collar      0.235745
# technician       0.164523
# services         0.099759
# management       0.071030
# entrepreneur     0.036445
# retired          0.035187
# self-employed    0.034804
# housemaid        0.026103
# unemployed       0.023804
# student          0.016417
# unknown          0.008017
# Name: job, dtype: float64
#
#  <yes>
# job
# admin.           0.291379
# technician       0.157328
# blue-collar      0.137500
# retired          0.093534
# management       0.070690
# services         0.069612
# student          0.059267
# self-employed    0.032112
# unemployed       0.031034
# entrepreneur     0.026724
# housemaid        0.022845
# unknown          0.007974
# Name: job, dtype: float64
# ----
#
#
# <no>
# marital
# married     0.612783
# single      0.272190
# divorced    0.113166
# unknown     0.001861
# Name: marital, dtype: float64
#
#  <yes>
# marital
# married     0.545690
# single      0.349138
# divorced    0.102586
# ...

# %%
#data=data.drop(columns=object_feature)

# %%
object_feature = [col for col in data.columns if data[col].dtypes == 'object' ]

# %%
df=pd.get_dummies(data, prefix=object_feature)

# %%
data.info()
#X=data.iloc[:,0:10]
X=df.iloc[:,0:63]
X
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
# age               41188 non-null int64
# job               41188 non-null object
# marital           41188 non-null object
# education         41188 non-null object
# default           41188 non-null object
# housing           41188 non-null object
# loan              41188 non-null object
# contact           41188 non-null object
# month             41188 non-null object
# day_of_week       41188 non-null object
# duration          41188 non-null int64
# campaign          41188 non-null int64
# pdays             41188 non-null int64
# previous          41188 non-null int64
# poutcome          41188 non-null object
# emp.var.rate      41188 non-null float64
# cons.price.idx    41188 non-null float64
# cons.conf.idx     41188 non-null float64
# euribor3m         41188 non-null float64
# nr.employed       41188 non-null float64
# y                 41188 non-null object
# ...

# %%
labelX=preprocessing.LabelEncoder()
y=labelX.fit_transform(y)
y
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
#standardscale function
def standardScale(df):
    #run standardscaling
    stand=preprocessing.StandardScaler()
    df2=stand.fit_transform(df)
    #return array after standardscaling
    return df2

# %%
X1=standardScale(X)

# %%
# Feature Importance
from sklearn import datasets
from sklearn import metrics
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
# load the iris datasets
# fit an Extra Trees model to the data
model = RandomForestClassifier()
model.fit(X1, y)
# display the relative importance of each attribute
print(model.feature_importances_)
# Out:
# [0.15408391 0.41813369 0.05796082 0.03893157 0.01895835 0.00981977
#  0.02166107 0.02770439 0.17025837 0.08248805]

# %%
feature_list = pd.concat([pd.Series(X.columns), pd.Series(model.feature_importances_)], axis=1)
feature_list.columns = ['features_name', 'importance']
feature_list.sort_values("importance", ascending =False).head(20)
# Out:
#      features_name  importance
# 1              job    0.418134
# 8            month    0.170258
# 0              age    0.154084
# 9      day_of_week    0.082488
# 2          marital    0.057961
# 3        education    0.038932
# 7          contact    0.027704
# 6             loan    0.021661
# 4          default    0.018958
# 5          housing    0.009820
# 10        duration         NaN
# 11        campaign         NaN
# 12           pdays         NaN
# 13        previous         NaN
# 14        poutcome         NaN
# 15    emp.var.rate         NaN
# 16  cons.price.idx         NaN
# 17   cons.conf.idx         NaN
# 18       euribor3m         NaN
# 19     nr.employed         NaN
